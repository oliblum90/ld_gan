# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
import ld_gan
from ld_gan import visualize
import numpy as np

# %% [markdown]
# # load data

# %%
X, Y = ld_gan.data_proc.data_loader.load_data(1, verbose=1, resize = 64)
# Out:
# 100%|██████████| 102/102 [00:15<00:00,  8.34it/s]
# load data from '/export/home/oblum/projects/ls_gan/data/flowers_102/jpg_128'

# %% [markdown]
# # visualize

# %%
enc = ld_gan.utils.model_handler.load_model("xf_enc.py", 500, "enc")
gen = ld_gan.utils.model_handler.load_model("xf_enc.py", 500, "gen")
# Out:
# loaded model 'projects/xf_enc.py/model/e_0500.pth'
# loaded model 'projects/xf_enc.py/model/g_0500.pth'

# %%
z = ld_gan.utils.model_handler.apply_model(enc, X[:10])
x = ld_gan.utils.model_handler.apply_model(gen, z)

# %%
from ld_gan.data_proc.transformer import np_to_tensor, tensor_to_np

# %%
visualize.disp(x)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
visualize.tsne_real_fake_vis(X, Y,  
                             "xf_enc.py", 
                             150,  
                             z_mapped = None,
                             n_neighbors = 1,
                             sampler=None,
                             alpha = 0.3,
                             n_pts_tsne = 4000)
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-493feea1fffb> in <module>()
#       6                              sampler=None,
#       7                              alpha = 0.3,
# ----> 8                              n_pts_tsne = 4000)
#
# /net/hciserver03/storage/oblum/projects/ld_gan/ld_gan/visualize.pyc in tsne_real_fake_vis(imgs_real, y, project, gen_epoch, z_mapped, sampler, n_pts_tsne, n_neighbors, alpha)
#     545     # load models
#     546     epoch_str = str(gen_epoch).zfill(4)
# --> 547     gen = load_model("projects/" + project + "/model/gen.h5")
#     548     gen.load_weights("projects/" + project + "/model/g_" + epoch_str + ".h5")
#     549     enc = load_model("projects/" + project + "/model/enc.h5", custom_objects={"tf": tf})
#
# /export/home/oblum/.local/lib/python2.7/site-packages/keras/models.pyc in load_model(filepath, custom_objects)
#     223         return obj
#     224
# --> 225     f = h5py.File(filepath, mode='r')
#     226
#     227     # instantiate model
#
# /usr/local/lib/python2.7/dist-packages/h5py/_hl/files.pyc in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     270
#     271                 fapl = make_fapl(driver, libver, **kwds)
# --> 272                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     273
#     274                 if swmr_support:
#
# /usr/local/lib/python2.7/dist-packages/h5py/_hl/files.pyc in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#      90         if swmr and swmr_support:
#      91             flags |= h5f.ACC_SWMR_READ
# ---> 92         fid = h5f.open(name, flags, fapl=fapl)
#      93     elif mode == 'r+':
#      94         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# /usr/lib/python2.7/dist-packages/h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/tmp/pip_build_root/h5py/h5py/_objects.c:2682)()
#      52     lock is needed, it acquires the lock and notifies the first thread
#      53     to release it when it's done.  This is all made possible by the
# ---> 54     wonderful GIL.
#      55     """
#      56     cdef pythread.PyThread_type_lock _real_lock
#
# /usr/lib/python2.7/dist-packages/h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/tmp/pip_build_root/h5py/h5py/_objects.c:2640)()
#      53     to release it when it's done.  This is all made possible by the
#      54     wonderful GIL.
# ---> 55     """
#      56     cdef pythread.PyThread_type_lock _real_lock
#      57     cdef long _owner            # ID of thread owning the lock
#
# /usr/lib/python2.7/dist-packages/h5py/h5f.pyx in h5py.h5f.open (/tmp/pip_build_root/h5py/h5py/h5f.c:1928)()
#      74 def create(char* name, int flags=H5F_ACC_TRUNC, PropFCID fcpl=None,
#      75                                                 PropFAID fapl=None):
# ---> 76     """(STRING name, INT flags=ACC_TRUNC, PropFCID fcpl=None,
#      77     PropFAID fapl=None) => FileID
#      78
#
# IOError: Unable to open file (Unable to open file: name = 'projects/xf_enc.py/model/gen.h5', errno = 2, error message = 'no such file or directory', flags = 0, o_flags = 0)
