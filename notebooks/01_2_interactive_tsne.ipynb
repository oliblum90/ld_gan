# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
import ld_gan
from ld_gan import visualize
import numpy as np

# %% [markdown]
# # load data

# %%
X, Y = ld_gan.data_proc.data_loader.load_data(1, verbose=1, resize = 64)
# Out:
# 100%|██████████| 102/102 [00:09<00:00, 12.23it/s]
# load data from '/export/home/oblum/projects/ls_gan/data/flowers_102/jpg_128'

# %%
yc = np.argmax(Y, axis = 1)

# %% [markdown]
# # visualize

# %%
visualize.tsne_real_fake_vis(X, yc,  
                             "xf_11111.py", 
                             850,  
                             z_mapped = None,
                             n_neighbors = 2,
                             sampler=None,
                             alpha = 0.3,
                             n_pts_tsne = 4000,
                             real_img_mode = "all+mean")
# Out:
# loaded model 'projects/xf_11111.py/model/e_0850.pth'
# loaded model 'projects/xf_11111.py/model/g_0850.pth'
# /net/hciserver03/storage/oblum/venvs/compvisgpu01/lib/python2.7/site-packages/torch/serialization.py:286: SourceChangeWarning: source code of class 'ld_gan.models.gen.Gen' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# <img src="data:image/png;base64,..." width="749.9999837441882">
