# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
import ld_gan
from ld_gan import visualize
import numpy as np
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked',)).History will not be written to the database.

# %% [markdown]
# # load data

# %%
X, Y, VF = ld_gan.tmp.load_imgs_and_vgg()
n_classes = Y.max()+1
# Out:
# 100%|██████████| 8184/8184 [03:07<00:00, 43.75it/s]
# /export/home/oblum/projects/ls_gan/data/flowers_102/jpg_128/39/image_07030.jpg

# %%
yc = Y

# %% [markdown]
# # visualize

# %%
visualize.tsne_real_fake_vis(X, yc,  
                             "xf_11110_vggenc.py", 
                             650,  
                             z_mapped = None,
                             n_neighbors = 5,
                             sampler=None,
                             alpha = 0.3,
                             n_pts_tsne = 4000,
                             real_img_mode = "all+mean",
                             is_parallel_model = False
                            )
# Out:
# loaded model 'projects/xf_11110_vggenc.py/model/e_0650.pth'
# loaded model 'projects/xf_11110_vggenc.py/model/g_0650.pth'
# compute tsne...
# <img src="data:image/png;base64,..." width="750">
