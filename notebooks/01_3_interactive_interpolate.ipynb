# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
import ld_gan
from ld_gan import visualize
import numpy as np

# %% [markdown]
# # load data

# %%
X, Y = ld_gan.data_proc.data_loader.load_data(1, verbose=1, resize = 64)
# Out:
# 100%|██████████| 102/102 [00:14<00:00,  6.84it/s]
# load data from '/export/home/oblum/projects/ls_gan/data/flowers_102/jpg_128'

# %% [markdown]
# # visualize

# %%
visualize.move_in_z_space("xf_enc.py", 
                          X[0], 
                          X[1], 
                          500)
# Out:
# loaded model 'projects/xf_enc.py/model/e_0500.pth'
# loaded model 'projects/xf_enc.py/model/g_0500.pth'
# <img src="data:image/png;base64,..." width="639.9999861283738">
