# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../../")

# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 3)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import ld_gan
import numpy as np

# %%
a = np.ones((32, 256))

# %%
a = ld_gan.data_proc.transformer.np_to_tensor(a)

# %%
for b in a.split(1):
    print b
# Out:
# Variable containing:
# ( 0 , 0 ,.,.) =
#   1
#
# ( 0 , 1 ,.,.) =
#   1
#
# ( 0 , 2 ,.,.) =
#   1
#
# ( 0 , 3 ,.,.) =
#   1
#
# ( 0 , 4 ,.,.) =
#   1
#
# ( 0 , 5 ,.,.) =
#   1
#
# ( 0 , 6 ,.,.) =
#   1
#
# ( 0 , 7 ,.,.) =
#   1
#
# ( 0 , 8 ,.,.) =
#   1
#
# ( 0 , 9 ,.,.) =
#   1
#
# ( 0 ,10 ,.,.) =
#   1
#
# ( 0 ,11 ,.,.) =
#   1
#
# ( 0 ,12 ,.,.) =
#   1
#
# ( 0 ,13 ,.,.) =
#   1
#
# ( 0 ,14 ,.,.) =
#   1
#
# ( 0 ,15 ,.,.) =
#   1
#
# ( 0 ,16 ,.,.) =
#   1
#
# ( 0 ,17 ,.,.) =
#   1
#
# ( 0 ,18 ,.,.) =
#   1
#
# ( 0 ,19 ,.,.) =
#   1
#
# ( 0 ,20 ,.,.) =
#   1
#
# ( 0 ,21 ,.,.) =
#   1
#
# ( 0 ,22 ,.,.) =
#   1
#
# ( 0 ,23 ,.,.) =
#   1
#
# ( 0 ,24 ,.,.) =
#   1
#
# ( 0 ,25 ,.,.) =
#   1
#
# ( 0 ,26 ,.,.) =
#   1
#
# ( 0 ,27 ,.,.) =
#   1
#
# ( 0 ,28 ,.,.) =
#   1
#
# ( 0 ,29 ,.,.) =
#   1
#
# ( 0 ,30 ,.,.) =
#   1
#
# ( 0 ,31 ,.,.) =
#   1
#
# ( 0 ,32 ,.,.) =
#   1
#
# ( 0 ,33 ,.,.) =
#   1
#
# ( 0 ,34 ,.,.) =
#   1
#
# ( 0 ,35 ,.,.) =
#   1
#
# ( 0 ,36 ,.,.) =
#   1
#
# ...

# %%
s = 0

# %%
s += 1

# %%
s
# Out:
# 1

# %%
from ld_gan.data_proc.data_loader import load_celeba

# %%
x, y = load_celeba()
# Out:
# ...
#   1%|          | 1375/202599 [00:01<36:56, 90.78it/s]
# 1377it [00:01, 90.52it/s]
# ...
#   9%|▉         | 17838/202599 [00:11<01:48, 1705.67it/s]
# 17838it [00:11, 1703.74it/s]
# ...
#  21%|██▏       | 43275/202599 [00:30<01:49, 1452.43it/s]
# 43276it [00:30, 1385.08it/s]
# ...
#  41%|████      | 82298/202599 [01:07<02:15, 887.46it/s]
# 82298it [01:07, 882.82it/s]
# ...
#  45%|████▍     | 90746/202599 [01:18<02:24, 775.36it/s]
# 90746it [01:18, 771.82it/s]
# ...
#  51%|█████     | 103625/202599 [01:35<01:57, 840.30it/s]
# ...
# ...
#  87%|████████▋ | 176530/202599 [04:07<1:10:55,  6.13it/s]
# 176530it [04:07, 14.68it/s]
# ...
#  96%|█████████▌| 194850/202599 [04:23<00:06, 1202.08it/s]
# 194850it [04:23, 1197.82it/s]
# ...
# 100%|█████████▉| 202531/202599 [04:30<00:00, 1006.25it/s]
# 202532it [04:30, 1006.63it/s]
# 100%|██████████| 202599/202599 [04:30<00:00, 749.47it/s]

# %%
import scipy.misc
from tqdm import tqdm
import os

# %%
path_scr = "/export/home/oblum/projects/ls_gan/data/celebA/jpg_128/faces"
path_dst = "/export/home/oblum/projects/ls_gan/data/celebA/jpg_64"

# %%
for name in tqdm(os.listdir(path_scr)):
    fname = os.path.join(path_scr, name)
    img = scipy.misc.imread(fname)
    img = scipy.misc.imresize(img, (64,64))
    fname = os.path.join(path_dst, name)
    scipy.misc.imsave(fname, img)
# Out:
# 100%|██████████| 202599/202599 [17:45<00:00, 190.15it/s]

# %%
from torch import nn

# %%
nn.Sigmoid()

# %%
a = np.zeros
