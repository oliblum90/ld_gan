# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
import ld_gan
import numpy as np
import scipy.misc
import ld_gan.utils.utils as ld
from tqdm import tqdm

# %% [markdown]
# # load fnames

# %%
fnames = ld.listdir("data/faceScrub/imgs_new", ".jpg", True)

# %% [markdown]
# # rename imgs

# %%
with open("../facescrub/facescrub_actors.txt", 'r') as f:
    content = f.read()
lines_1 = content.split("\n")[1:-1]

with open("../facescrub/facescrub_actresses.txt", 'r') as f:
    content = f.read()
lines_2 = content.split("\n")[1:-1]

lines = lines_1 + lines_2

# %%
for line in tqdm(lines):
    
    splits = line.split("\t")
    name = splits[0]
    face_id = splits[2]
    code = splits[-1]
    
    fname_new = "_".join(name.split(" ")) + "/" + \
                "_".join(name.split(" ")) + \
                "_" + face_id + ".jpg"
    fname_old = "_".join(name.split(" ")) + "/" + code + ".jpg"
    
    fname_new = os.path.join("data/faceScrub/imgs_new/", fname_new)
    fname_old = os.path.join("data/faceScrub/imgs_new/", fname_old)
    
    print fname_old
    print fname_new
    
    raw_input()
    #os.rename(fname_old, fname_new)
# Out:
#   0%|          | 0/107818 [00:00<?, ?it/s]
# data/faceScrub/imgs_new/Aaron_Eckhart/dec996994cf1eec33b53c203cff0e8f25638829fa2ad71bb0307d308fa11cdac.jpg
# data/faceScrub/imgs_new/Aaron_Eckhart/Aaron_Eckhart_1.jpg
#   0%|          | 1/107818 [00:01<40:56:10,  1.37s/it]
# data/faceScrub/imgs_new/Aaron_Eckhart/f84d0c3b1b854a51e6bc031bc353e801834e81df795e85ec1589ca895fb7c1ae.jpg
# data/faceScrub/imgs_new/Aaron_Eckhart/Aaron_Eckhart_2.jpg

# %%
line
# Out:
# 'Aaron Eckhart\t5\t5\thttp://upload.wikimedia.org/wikipedia/commons/5/5e/Aaron-Eckhart-Traveling.jpg\t276,120,492,336\t1fa14fed3371280e8785df42cdc5d0335e7923a38f1b0632e3b88a52e850825f'

# %%
fnames[0]
# Out:
# 'data/faceScrub/imgs_new/Gates_McFadden/f657cb7c54f03095f831e44f710ccaa3a63b6878.jpg'

# %%
len(fnames)
# Out:
# 146902

# %%
os.listdir("data/faceScrub/imgs_new/Aaron_Eckhart/face/fa14f")
# Out:
# ['9c0ae78021143c988594763bcc4a54d2cce5a17a.jpg',
#  'face',
#  '_bboxes.txt',
#  'fe3cfc689ce4ae4f8c7fd7a28c44f3a58fd971a6.jpg',
#  '1d05dd985ee7a6bb9e17895bd4739bebe6ae8f8d.jpg',
#  'ec1d88969f624a399ab5aa7df28689c263b9450f.jpg',
#  '7fcc6421f152065b86c10853183307899f2e6ae9.jpg',
#  'e3addd80da2e6a7f095d3c133675be473b5c38dd.jpg',
#  'ec3ee057004182dc50a6b929b994737388c3d006.jpg',
#  '3977224636c5c7cfc7bf23068f1e17e51c43e146.jpg',
#  'ddf14736665271a7131ab898e5f072516de12ee5.jpg',
#  'c4671ca46599d374b96954492042b48720f24fcc.jpg',
#  'c857f53fc6fe55e14685a998acc13f21984c7ee9.jpg',
#  '9653d5eb717cd144c6d80f4d5124fea62565c8fe.jpg',
#  'b837db1058c0e2731732acfb3618407237a3a52e.jpg',
#  '932257a1d31317acdbfbdd0372f918249ae10d4f.jpg',
#  '0de49b52c4db40e876d2fad7130add059f886f62.jpg',
#  '1328632de5dbc3cfaa52bf9fc3a07bf46443c556.jpg',
#  '02454bf4214b50ea5df5bc01498f474471356363.jpg',
#  'beb4e705d7c9fb997d7ed8e9a75a9069d6feb244.jpg',
#  '8bdca9bb79055451a068d24135508111b4003c02.jpg',
# ...

# %%
temp = ld.listdir("/export/home/oblum/projects/facescrub/download/", ".jpg", True)

# %%
len(temp) / 2.
# Out:
# 74340.0

# %%
temp[:10]
# Out:
# ['../facescrub/download/Alley_Mills/Alley_Mills_51940.jpg',
#  '../facescrub/download/Alley_Mills/Alley_Mills_51942.jpg',
#  '../facescrub/download/Alley_Mills/Alley_Mills_51944.jpg',
#  '../facescrub/download/Alley_Mills/Alley_Mills_51946.jpg',
#  '../facescrub/download/Alley_Mills/Alley_Mills_51947.jpg',
#  '../facescrub/download/Alley_Mills/Alley_Mills_51948.jpg',
#  '../facescrub/download/Alley_Mills/Alley_Mills_51949.jpg',
#  '../facescrub/download/Alley_Mills/Alley_Mills_51951.jpg',
#  '../facescrub/download/Alley_Mills/Alley_Mills_51952.jpg',
#  '../facescrub/download/Alley_Mills/Alley_Mills_51953.jpg']

# %%
img = scipy.misc.imread("../script_AlignFaceAndSave/FacescrubAlign/Aaron_Eckhart/Aaron_Eckhart_10.jpg")

# %%
ld.disp(img)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
img = scipy.misc.imread("data/faceScrub/crop_train/")
