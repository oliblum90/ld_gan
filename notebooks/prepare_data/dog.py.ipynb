# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
import ld_gan as ld
import scipy.misc
import numpy as np

# %%
fnames = ld.listdir("data/dogs/Images/n02085620-Chihuahua/")

# %%
imgs = [scipy.misc.imread(n) for n in fnames]

# %%
ld.disp(imgs[:10])
# Out:
# <img src="data:image/png;base64,..." width="640">
