# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
from ld_gan import visualize
import numpy as np
import ld_gan

# %% [markdown]
# # load data

# %%
X, Y = ld_gan.data_proc.data_loader.load_data(4, verbose=1, resize = 64)
yc = np.argmax(Y, axis = 1)
# Out:
# 100%|██████████| 35/35 [00:11<00:00,  3.67it/s]
# load data from '/export/home/oblum/projects/ld_gan/data/pets/cropped'

# %% [markdown]
# # show

# %%
visualize.tsne_to_interpol_arr(X, yc,  
                               "xp_111v1.py", 
                               400,  
                               z_mapped = None,
                               n_neighbors = 4,
                               sampler=None,
                               alpha = 0.3,
                               n_pts_tsne = 4000,
                               real_img_mode = "all+mean",
                               small = False,
                               recompute_tsne = True
                              )
# Out:
# loaded model 'projects/xp_111v1.py/model/e_0400.pth'
# loaded model 'projects/xp_111v1.py/model/g_0400.pth'
# compute tsne...
# <img src="data:image/png;base64,..." width="1000">
