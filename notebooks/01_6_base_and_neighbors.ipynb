# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib inline
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
from ld_gan import visualize
import numpy as np
import ld_gan
import sklearn

# %% [markdown]
# # load data

# %%
X, Y = ld_gan.data_proc.data_loader.load_data(1, verbose=1, resize = 64)
# Out:
# 100%|██████████| 102/102 [00:16<00:00,  6.26it/s]
# load data from '/export/home/oblum/projects/ls_gan/data/flowers_102/jpg_128'

# %%
yc = np.argmax(Y, axis = 1)

# %% [markdown]
# # show

# %%
visualize.show_base_and_neighbors("xf_11111_s10l_trip_2.py", X, 70)
# Out:
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0000.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0050.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0100.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0150.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0200.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0250.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0300.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0350.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0400.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0450.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0500.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0550.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0600.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0650.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0700.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0750.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0800.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0850.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0900.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_0950.pth'
# loaded model 'projects/xf_11111_s10l_trip_2.py/model/e_1000.pth'

# %%
for i in range(20):
    p = i*10
    visualize.disp(X[p:p+10])

# %%
path = os.path.join("projects", project, "model")
epochs = [int(g[2:6]) for g in os.listdir(path) if "g_" in g]

# %%
sorted(epochs)
# Out:
# [0, 5]
