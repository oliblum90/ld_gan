# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
from ld_gan import visualize
import numpy as np
import ld_gan

# %% [markdown]
# # load data

# %%
X, Y = ld_gan.data_proc.data_loader.load_data(2, verbose=1)
# Out:
# 100%|██████████| 6/6 [12:55<00:00, 120.71s/it]
# load data from '/export/home/oblum/projects/ld_gan/data/celebA/jpg_64'

# %%
yc = np.argmax(Y, axis = 1)

# %% [markdown]
# # show

# %%
visualize.tsne_to_interpol_arr(X, yc,  
                               "xc_111v1_sss10k.py", 
                               20,  
                               z_mapped = None,
                               n_neighbors = 4,
                               sampler=None,
                               alpha = 0.3,
                               n_pts_tsne = 4000,
                               real_img_mode = "all+mean",
                               small = False,
                               recompute_tsne = True
                              )
# Out:
# loaded model 'projects/xc_111v1_sss10k.py/model/e_0020.pth'
# loaded model 'projects/xc_111v1_sss10k.py/model/g_0020.pth'
# compute tsne...
# <img src="data:image/png;base64,..." width="1000">
