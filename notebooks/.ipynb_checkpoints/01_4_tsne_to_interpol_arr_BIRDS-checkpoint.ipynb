# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
from ld_gan import visualize
import numpy as np
import ld_gan

# %% [markdown]
# # load data

# %%
#X, Y, VF = ld_gan.tmp.load_imgs_and_vgg()
#n_classes = Y.max()+1

X, Y = ld_gan.data_proc.data_loader.load_data(3, verbose=1, resize = 64)

#X, Y = ld_gan.data_proc.data_loader.load_data(1, verbose=1)
# Out:
# 100%|██████████| 200/200 [01:36<00:00,  2.69it/s]
# load data from '/export/home/oblum/projects/ld_gan/data/birds/images'

# %%
#yc = Y
yc = np.argmax(Y, axis = 1)

# %% [markdown]
# # show

# %%
#xf_11111_ri.py
visualize.tsne_to_interpol_arr(X, yc,  
                               "xb_11111.py", 
                               500,  
                               z_mapped = None,
                               n_neighbors = 4,
                               sampler=None,
                               alpha = 0.3,
                               n_pts_tsne = 4000,
                               real_img_mode = "all+mean",
                               small = False
                              )
# Out:
# loaded model 'projects/xb_11111.py/model/e_0350.pth'
# loaded model 'projects/xb_11111.py/model/g_0350.pth'
# compute tsne...
# <img src="data:image/png;base64,..." width="1000">
