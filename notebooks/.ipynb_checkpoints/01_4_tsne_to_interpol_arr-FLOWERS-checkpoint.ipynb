# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
from ld_gan import visualize
import numpy as np
import ld_gan

# %% [markdown]
# # load data

# %%
X, Y = ld_gan.data_proc.data_loader.load_data(1, verbose=1, resize = 64)
yc = np.argmax(Y, axis = 1)
# Out:
# 100%|██████████| 102/102 [00:59<00:00,  2.08it/s]
# load data from '/export/home/oblum/projects/ld_gan/data/flowers_102/jpg_256'

# %% [markdown]
# # show

# %%
visualize.tsne_to_interpol_arr(X, yc,  
                              "xf_111v1_gclf2.py", 
                               200,  
                               z_mapped = None,
                               n_neighbors = 4,
                               sampler=None,
                               alpha = 0.3,
                               n_pts_tsne = 4000,
                               real_img_mode = "all+mean",
                               small = False,
                               recompute_tsne = True
                              )
# Out:
# loaded model 'projects/xf_111v1_gclf2.py/model/e_0200.pth'
# loaded model 'projects/xf_111v1_gclf2.py/model/g_0200.pth'
# <img src="data:image/png;base64,..." width="1000">
