# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
from ld_gan import visualize
import numpy as np
import ld_gan
import ld_ganan.utils.utils as ld

# %% [markdown]
# # load data

# %%
X, Y = ld_gan.data_proc.data_loader.load_data(1, verbose=1, resize = 64)
yc = np.argmax(Y, axis = 1)
# Out:
# 100%|██████████| 102/102 [01:14<00:00,  1.83it/s]
# load data from '/export/home/oblum/projects/ld_gan/data/flowers_102/jpg_256'

# %% [markdown]
# # show

# %%
visualize.tsne_to_interpol_arr(X, yc,  
                              "xf_111v1_gclf_scs.py", 
                               550,
                               z_mapped = None,
                               n_neighbors = 4,
                               sampler=None,
                               alpha = 0.3,
                               n_pts_tsne = 4000,
                               real_img_mode = "all+mean",
                               small = False,
                               nn_within_class = True,
                               recompute_tsne = True
                              )
# Out:
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:1': 'cuda:0'}
# loaded model 'projects/xf_111v1_gclf_scs.py/model/e_0550.pth'
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:1': 'cuda:0'}
# loaded model 'projects/xf_111v1_gclf_scs.py/model/g_0550.pth'
# compute tsne...
# <img src="data:image/png;base64,..." width="1000">
# (8188,) (4000, 2)

# %%
visualize.tsne_to_interpol_arr()

# %%
path_scr = "data/flowers_102/corner_imgs/"
project, epoch = "xf_111v1_gclf_scs.py", 550

# %%
visualize.generate_corner_imgs(project, epoch, path_scr)
# Out:
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:1': 'cuda:0'}
# loaded model 'projects/xf_111v1_gclf_scs.py/model/e_0550.pth'
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:
# 100%|██████████| 105/105 [00:45<00:00,  4.49it/s]
#  {'cuda:1': 'cuda:0'}
# loaded model 'projects/xf_111v1_gclf_scs.py/model/g_0550.pth'

# %%
fnames = ld.listdir("projects/xf_111v1_gclf_scs.py/interpol_arr/")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-1aaa385d9b9e> in <module>()
# ----> 1 fnames = ld.listdir("projects/xf_111v1_gclf_scs.py/interpol_arr/")
#
# NameError: name 'ld' is not defined
