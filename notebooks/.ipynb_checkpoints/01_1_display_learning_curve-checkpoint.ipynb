# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
from ld_gan import visualize
import numpy as np
import ld_gan
from ld_gan.visualize import gpu 
import ld_gan.utils.utils as ld

# %%
gpu(3000)
# Out:
# name                           host             epoch                     gpu
# ------------------------------------------------------------------------------
# xS_111v1_nnscs.py              hgsgpu02         1.0      (5.91 h/epc)      1
# xf_111v1_nnscs_trip.py         compvisgpu04     561.48   (5.39 m/epc)      1
# xs_111v0.py                    hcigpu04         27.8     (32.2 m/epc)      3
# xs_111v0_trip.py               hgsgpu02         10.85    (1.58 h/epc)      7
# xs_111v1_nnscs_new.py          compvisgpu03     88.47    (23.4 m/epc)      1
# xs_111v1_nnscs_trip.py         compvisgpu03     39.49    (1.33 h/epc)      2
# xs_111v1_nnscs_trip_f5.py      compvisgpu03     84.77    (34.8 m/epc)      0
# ------------------------------------------------------------------------------
#
#
# 7 projects running

# %%
np.loadtxt("projects/xs_111v1_nnscs_trip_f5.py/log/iscore.txt", skiprows=1)
# Out:
# array([ 1.67001,  1.90265,  1.96024,  1.97958,  1.92894,  1.85947,
#         1.93231,  1.98568,  1.92408])

# %%
# xS_111v1_gclf_scs_new
# xs_111v1_gclf_scs_new.py
# xf_111v1_nnscs.py

# %%
visualize.learning_curve_ia(
                            "xs_111v0.py", 
                            high_res=True,
                            show_hist_tsne=True,
                            #ymax=5, xmax=100,
                            mean=True,
                            #logs_fname = "dis_score.txt"
                            #logs_fname = "clf_acc.txt"
                            )
# Out:
# <img src="data:image/png;base64,..." width="1350">

# %%
visualize.learning_curve_ia(
                            "xf_111v1_nnscs.py", 
                            high_res=True,
                            show_hist_tsne=True,
                            ymax=5, xmax=100,
                            mean=True,
                            #logs_fname = "dis_score.txt"
                            #logs_fname = "clf_acc.txt"
                            )
# Out:
# <img src="data:image/png;base64,..." width="1350">

# %%
"eval_imgs/xS_111v1_gclf_scs_new.py_E30/"

# %%
"da"

# %%
np.loadtxt("projects/xS_111v1_gclf_scs_new.py/log/iscore.txt", skiprows=1)
# Out:
# array([ 1.71983,  1.87482,  1.9643 ,  2.03633,  1.95291,  1.73759,
#         2.41846,  1.9289 ,  2.01788])

# %%
np.loadtxt("projects/xs_111v1_nnscs_trip_f5.py/log/iscore.txt", skiprows=1)
# Out:
# array([ 1.67001,  1.90265,  1.96024,  1.97958,  1.92894,  1.85947])

# %%
np.loadtxt("projects/xs_111v1_nnscs_trip.py/log/iscore.txt", skiprows=1)
# Out:
# array([ 1.91985,  1.93762,  1.94009])

# %%
np.loadtxt("projects/xs_111v1_nnscs_new.py/log/iscore.txt", skiprows=1)
# Out:
# array([ 1.64536,  2.04501,  1.93387,  1.92907,  1.87656,  1.90765])

# %%
np.loadtxt("projects/xs_111v0.py/log/iscore.txt", skiprows=1)
# Out:
# array(2.12523)

# %%
2.04 / 2.29
# Out:
# 0.8908296943231441

# %%
19.03 / 20.85
# Out:
# 0.9127098321342926

# %%
2.29 * 0.9127098321342926
# Out:
# 2.09010551558753

# %%
2.41 / 3.28
# Out:
# 0.7347560975609757

# %%
ld.listdir("../script_AlignFaceAndSave/")
