# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
from ld_gan import visualize
import numpy as np
import ld_gan

# %%
visualize.learning_curve_ia(
                            "xf_111111.py", 
                            high_res=True,
                            show_hist_tsne=True,
                            logs_fname = "dis_score.txt", 
                            #ymax=1
                            )
# Out:
# <img src="data:image/png;base64,..." width="1350">

# %%
# cancel
visualize.learning_curve_ia(
                            "xf_111101.py", 
                            high_res=True,
                            show_hist_tsne=True,
                            mean=True,
                            #logs_fname = "dis_score.txt", 
                            #ymax=1
                            )
# Out:
# <img src="data:image/png;base64,..." width="1350">

# %%
visualize.learning_curve_ia(
                            "xf_111111_nP.py", 
                            high_res=True,
                            show_hist_tsne=True,
                            mean=True,
                            #logs_fname = "dis_score.txt", 
                            #ymax=1
                            )
# Out:
# <img src="data:image/png;base64,..." width="1350">

# %%
visualize.learning_curve_ia(
                            "xf_111101_nP.py", 
                            high_res=True,
                            show_hist_tsne=True,
                            logs_fname = "dis_score.txt",
                            mean = True,
                            )
# Out:
# <img src="data:image/png;base64,..." width="1350">

# %% [markdown]
# # xc

# %%
visualize.learning_curve_ia(
                            "xc_11111_s10l.py", 
                            high_res=True,
                            show_hist_tsne=True,
                            ymax=5,
                            #logs_fname = "clf_acc.txt"
                            #logs_fname = "incept_score.txt",
                            )
# Out:
# <img src="data:image/png;base64,..." width="1350">

# %%
visualize.time_eval("xc_11111_s10l.py")
# Out:
# <img src="data:image/png;base64,..." width="640">
