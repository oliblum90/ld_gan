# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
from ld_gan import visualize
import numpy as np

# %%
visualize.learning_curve_ia("xf_enc.py")
# Out:
# <img src="data:image/png;base64,..." width="749.9999837441882">
