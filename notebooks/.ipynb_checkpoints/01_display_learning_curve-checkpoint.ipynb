# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from ld_gan import visualize

# %%
visualize.learning_curve("x_test.py")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-c3aa96bcd499> in <module>()
# ----> 1 visualize.learning_curve("x_test.py")
#
# /net/hciserver03/storage/oblum/projects/ld_gan/ld_gan/visualize.py in learning_curve(project, path, smooth, show_disc, show_gen_d, show_gen_e, show_gen_img, iters_per_epoch, max_epoch, gen_img_epoch, xmax, ymax, show_hist_tsne)
#     193
#     194     if show_gen_e:
# --> 195         plt.plot(x, logs[:,2], c='r', alpha = 0.2)
#     196         y = np.convolve(logs[:,2],
#     197                         np.ones((smooth,))/smooth,
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
np.loadtxt(skiprows=1, delimiter=" ")
