# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
from ld_gan import visualize
import numpy as np
import ld_gan
import scipy.misc
from tqdm import tqdm
import ld_gan.utils.utils as ld
import ld_gan

# %% [markdown]
# # load data

# %%
path = "data/faceScrub/imgs_top_aligned/"
X, Y = ld_gan.data_proc.data_loader.load_data(path, resize=128, test_train="train")
Y = np.argmax(Y, axis = 1)
# Out:
#  16%|█▌        | 84/523 [00:15<02:37,  2.78it/s]

# %%
path = "data/faceScrub/imgs_top_aligned/"
Xt, Yt = ld_gan.data_proc.data_loader.load_data(path, resize=128, test_train="test")
Yt = np.argmax(Yt, axis = 1)

# %%
X_64 = np.array([scipy.misc.imresize(x, (64,64)) for x in tqdm(X)])
Xt_64 = np.array([scipy.misc.imresize(x, (64,64)) for x in tqdm(Xt)])

# %% [markdown]
# # show

# %%
# xs_111v1_gclf_scs_new
visualize.tsne_to_interpol_arr(X_64, Y,  
                              "XS_111v1_nnscs.py", 
                               10,
                               z_mapped = None,
                               n_neighbors = 4,
                               sampler=None,
                               alpha = 0.3,
                               n_pts_tsne = 10000,
                               real_img_mode = "all+mean",
                               small = False,
                               nn_within_class = True,
                               recompute_tsne = True
                              )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-63f49617f20f> in <module>()
#       1 # xs_111v1_gclf_scs_new
# ----> 2 visualize.tsne_to_interpol_arr(X_64, Y,
#       3                               "Xs_111v1_nnscs_trip_f5.py",
#       4                                20,
#       5                                z_mapped = None,
#
# NameError: name 'visualize' is not defined

# %%
#xs_111v0
#Xs_111v1_nnscs_trip_f5
#xs_111v0_trip

train_imgs, test_imgs = visualize.make_corner_imgs("xs_111v0.py", 
                                                   None, 
                                                   128,
                                                   save = True)
# Out:
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/e_0010.pth'
# enc
# enc
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/g_0010.pth'
# gen
# gen
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/e_0020.pth'
# enc
# enc
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/g_0020.pth'
# gen
# gen
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/e_0030.pth'
# enc
# enc
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/g_0030.pth'
# gen
# gen
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/e_0040.pth'
# enc
# enc
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/g_0040.pth'
# gen
# gen
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/e_0050.pth'
# enc
# enc
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/g_0050.pth'
# gen
# gen
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/e_0060.pth'
# enc
# enc
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/g_0060.pth'
# gen
# gen
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/e_0070.pth'
# enc
# enc
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/g_0070.pth'
# gen
# gen
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/e_0080.pth'
# enc
# enc
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/g_0080.pth'
# gen
# gen
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/e_0090.pth'
# enc
# enc
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/g_0090.pth'
# gen
# gen
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/e_0100.pth'
# enc
# enc
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/g_0100.pth'
# gen
# gen
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/e_0110.pth'
# enc
# enc
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/g_0110.pth'
# gen
# gen
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/e_0120.pth'
# enc
# enc
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/g_0120.pth'
# gen
# gen
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/e_0130.pth'
# enc
# enc
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/g_0130.pth'
# gen
# gen
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/e_0140.pth'
# enc
# enc
# 1
# 1
# 1
# 1
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:3': 'cuda:0'}
# loaded model 'projects/xs_111v0.py/model/g_0140.pth'
# gen
# gen
# 1
# 1
# 1
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-23c66a37dbe0> in <module>()
#       5                                                    None,
#       6                                                    128,
# ----> 7                                                    save = True)
#
# TypeError: 'NoneType' object is not iterable

# %%
os.listdir("projects/" + project + "/model/")
# Out:
# ['gen.pth',
#  'dis.pth',
#  'enc.pth',
#  'g_0000.pth',
#  'd_0000.pth',
#  'e_0000.pth',
#  'g_0010.pth',
#  'd_0010.pth',
#  'e_0010.pth',
#  'g_0020.pth',
#  'd_0020.pth',
#  'e_0020.pth',
#  'g_0030.pth',
#  'd_0030.pth',
#  'e_0030.pth',
#  'g_0040.pth',
#  'd_0040.pth',
#  'e_0040.pth',
#  'g_0050.pth',
#  'd_0050.pth',
#  'e_0050.pth',
#  'g_0060.pth',
#  'd_0060.pth',
#  'e_0060.pth']

# %%
models = os.listdir("projects/" + project + "/model/")
epochs = [int(m[2:-4]) for m in models if "d_" in m]

# %%
epochs
# Out:
# [0, 10, 20, 30, 40, 50, 60]

# %%
ld.disp(train_imgs[3])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#TEST
idxs_test = [[983, 986, 974, 978]
             [601, 596, 594, 588]
             [313, 314, 315, 319]
             [59,  55,  52,  66]
             [29,  34,  30,  31]

# %%
#TRAIN
idxs_train = [[432, 351, 337, 448],
              [958, 911, 984, 910],
              [604, 597, 591, 592],
              [517, 484, 561, 498],
              [506, 539, 509, 523]]

# %%
resize = 128

# %%
fnames = sorted(ld.listdir("data/faceScrub/imgs_top_aligned/", ".jpg", True))
fnames_test = [fname for fname in fnames if "_test" in fname]
fnames_train = [fname for fname in fnames if "_test" not in fname]

# %%
fnames_test = np.array(fnames_test)
fnames_train = np.array(fnames_train)

# %%
project, epoch = "XS_111v1_gclf_scs_new.py", 20
enc = ld_gan.utils.model_handler.load_model(project, epoch, "enc")
gen = ld_gan.utils.model_handler.load_model(project, epoch, "gen")
# Out:
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:6': 'cuda:0'}
# loaded model 'projects/XS_111v1_gclf_scs_new.py/model/e_0020.pth'
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:6': 'cuda:0'}
# loaded model 'projects/XS_111v1_gclf_scs_new.py/model/g_0020.pth'

# %%
c_imgs = []
for idxs in idxs_train:
    fnames = fnames_train[np.array(idxs)]
    imgs = [scipy.misc.imread(fname) for fname in fnames]
    imgs = np.array([scipy.misc.imresize(img, (resize,resize)) for img in imgs])
    c_img = visualize.make_corner_img(imgs, enc, gen)
    c_imgs.append(c_img)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-b7aa11914790> in <module>()
#       6     c_img = visualize.make_corner_img(imgs, enc, gen)
#       7     ld.disp(c_img)
# ----> 8     raw_input()
#
# /usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.pyc in raw_input(self, prompt)
#     675             self._parent_ident,
#     676             self._parent_header,
# --> 677             password=False,
#     678         )
#     679
#
# /usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.pyc in _input_request(self, prompt, ident, parent, password)
#     705             except KeyboardInterrupt:
#     706                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 707                 raise KeyboardInterrupt
#     708             else:
#     709                 break
#
# KeyboardInterrupt:
