# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
import ld_gan
from ld_gan import visualize
import numpy as np

# %% [markdown]
# # load data

# %%
X, Y = ld_gan.data_proc.data_loader.load_data(1, verbose=1, resize = 64)
# Out:
# 100%|██████████| 102/102 [00:13<00:00,  7.72it/s]
# load data from '/export/home/oblum/projects/ls_gan/data/flowers_102/jpg_128'

# %%
yc = np.argmax(Y, axis = 1)

# %% [markdown]
# # visualize

# %%
visualize.tsne_real_fake_vis(X, yc,  
                             "xf_11000_s10.py", 
                             700,  
                             z_mapped = None,
                             n_neighbors = 5,
                             sampler=None,
                             alpha = 0.3,
                             n_pts_tsne = 4000,
                             real_img_mode = "all+mean")
# Out:
# loaded model 'projects/xf_11000_s10.py/model/enc.pth'
# loaded model 'projects/xf_11000_s10.py/model/g_0100.pth'
# compute tsne...
# <img src="data:image/png;base64,..." width="749.9999837441882">
