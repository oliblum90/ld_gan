# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
from ld_gan import visualize
import numpy as np
import ld_gan

# %% [markdown]
# # load data

# %%
X, Y = ld_gan.data_proc.data_loader.load_data(10, verbose=1, resize = 128)
# Out:
# 100%|██████████| 102/102 [00:46<00:00,  2.71it/s]
# load data from '/export/home/oblum/projects/ld_gan/data/flowers_102/jpg_train_256'

# %%
yc = np.argmax(Y, axis = 1)

# %% [markdown]
# # show

# %%
visualize.tsne_to_interpol_arr(X, yc,  
                               "xF_111v1_new.py", 
                               300,  
                               z_mapped = None,
                               n_neighbors = 4,
                               sampler=None,
                               alpha = 0.3,
                               n_pts_tsne = 4000,
                               real_img_mode = "all+mean",
                               small = False,
                               nn_within_class = True,
                               #recompute_tsne = True
                              )
# Out:
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:1': 'cuda:0'}
# loaded model 'projects/xF_111v1_new.py/model/e_0300.pth'
# cuda runtime error (10) : invalid device ordinal at torch/csrc/cuda/Module.cpp:87
# found gpu mapping:  {'cuda:1': 'cuda:0'}
# loaded model 'projects/xF_111v1_new.py/model/g_0300.pth'
# <img src="data:image/png;base64,..." width="1000">
