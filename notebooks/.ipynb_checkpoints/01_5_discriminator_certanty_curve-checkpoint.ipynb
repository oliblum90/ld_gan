# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
from ld_gan import visualize
import numpy as np
import ld_gan

# %% [markdown]
# # load data

# %%
X, Y = ld_gan.data_proc.data_loader.load_data(1, verbose=1, resize = 64)
# Out:
# 100%|██████████| 102/102 [00:18<00:00,  5.46it/s]
# load data from '/export/home/oblum/projects/ls_gan/data/flowers_102/jpg_128'

# %%
yc = np.argmax(Y, axis = 1)

# %% [markdown]
# # show

# %%
visualize.discriminator_certanty_curve(X, yc,
                                       "xf_11111_s10l.py", 
                                       650,
                                       dis_score_mode = 'min',
                                       loss = None
                                      )
# Out:
# loaded model 'projects/xf_11111_s10l.py/model/e_0650.pth'
# loaded model 'projects/xf_11111_s10l.py/model/g_0650.pth'
# loaded model 'projects/xf_11111_s10l.py/model/d_0650.pth'
# [autoreload of ld_gan.visualize failed: Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
#   File "ld_gan/visualize.py", line 944
#     vmin=ymin., vmax=ymax)
#               ^
# SyntaxError: invalid syntax
# ]
# <img src="data:image/png;base64,..." width="1000">
