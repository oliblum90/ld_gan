# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib inline
import matplotlib.pylab as plt

# %%
from matplotlib import pylab
pylab.rcParams['figure.figsize'] = (10, 5)

# %%
import ld_gan
from time import time
import numpy as np
from ld_gan.utils.model_handler import apply_model
import sklearn
from ld_gan.visualize import disp

# %%
n_interpol = 10

# %%
X, Y = ld_gan.data_proc.data_loader.load_data(2, verbose=1)
# Out:
# 100%|██████████| 6/6 [09:11<00:00, 82.02s/it]
# load data from '/export/home/oblum/projects/ld_gan/data/celebA/jpg_64'

# %%
project , epoch = "xc_11111.py", 9
enc = ld_gan.utils.model_handler.load_model(project , epoch, "enc")
gen = ld_gan.utils.model_handler.load_model(project , epoch, "gen")
dis = ld_gan.utils.model_handler.load_model(project , epoch, "dis")
# Out:
# loaded model 'projects/xc_11111.py/model/e_0009.pth'
# loaded model 'projects/xc_11111.py/model/g_0009.pth'
# loaded model 'projects/xc_11111.py/model/d_0009.pth'

# %%
z_all = ld_gan.utils.model_handler.apply_model(enc, X, 256)

# %%
sampler = ld_gan.sample.nn_sampler_life(enc, 
                                        X, Y, 
                                        256, 
                                        nn_search_radius = 50,
                                        n_neighbors = 5)

# %%
x_batch, y_batch, z_batch, batch_idxs, nn_idxs, sr_idxs = sampler.next()

# %%
trip_enc = ld_gan.train_ops.TripletEnc(enc, gen, dis, X, 0.0001, 
                                       logging=False, visualize=True)

# %%
loss = trip_enc.train(x_batch, y_batch, z_batch, batch_idxs, nn_idxs, sr_idxs, z_all)

# %%
z_all = ld_gan.utils.model_handler.apply_model(enc,  X, 256)

# %%
zs_potential = z_all[sr_idxs]

# %%
zs_potential.shape
# Out:
# (256, 50, 512)

# %%
zs_anc = z_all[batch_idxs]

# %%
zs_anc.shape
# Out:
# (256, 512)

# %%
batch_size = zs_end.shape[0]
n_sr_zs    = zs_end.shape[1]
n_features = zs_end.shape[2]

zs_paths = np.zeros((n_interpol, batch_size, n_sr_zs, n_features))
for i1 in range(n_interpol):
    for i2 in range(batch_size):
        for i3 in range(n_sr_zs):
            f1 = (i1+1)/float(n_interpol+1)
            f2 = 1 - f1
            zs_paths[i1, i2, i3, :] = f1*zs_anc[i2] + f2*zs_potential[i2, i3]

# %%
zs = zs_paths.reshape(-1, n_features)

# %%
ds = ld_gan.utils.model_handler.apply_models(zs, 1000, gen, dis)

# %%
ds = ds.reshape((n_interpol, batch_size, n_sr_zs))

# %%
ds.shape
# Out:
# (10, 256, 50)

# %%
ds = np.min(ds, axis=0)

# %%
ds.shape
# Out:
# (256, 50)

# %%
idx_current = 0
sa = np.argsort(-ds[idx_current])
imgs = X[sr_idxs][idx_current]
imgs = np.array([imgs[i] for i in sa])
scores = ds[idx_current]
scores = [scores[i] for i in sa]

ld_gan.visualize.disp([x_batch[idx_current]])
ld_gan.visualize.disp_array(imgs, (5,10))

# %%
sa.shape
# Out:
# (50,)

# %%
X[sr_idxs].shape
# Out:
# (256, 50, 64, 64, 3)

# %%
sa[-5:].shape
# Out:
# (5,)

# %%
np.random.randint(0, 5)
# Out:
# 4

# %%
ld_gan.visualize.out()
