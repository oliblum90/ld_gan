# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
from ld_gan import visualize
import numpy as np
import ld_gan

# %% [markdown]
# # load data

# %%
X, Y, VF = ld_gan.tmp.load_imgs_and_vgg()
n_classes = Y.max()+1
# Out:
# 100%|██████████| 8184/8184 [00:13<00:00, 589.89it/s]
# /export/home/oblum/projects/ls_gan/data/flowers_102/jpg_128/39/image_07030.jpg

# %%
yc = Y

# %% [markdown]
# # show

# %%
visualize.tsne_to_interpol_arr(X, yc,  
                               "xf_11110_vggenc.py", 
                               1000,  
                               z_mapped = None,
                               n_neighbors = 4,
                               sampler=None,
                               alpha = 0.3,
                               n_pts_tsne = 4000,
                               real_img_mode = "all+mean",
                               small = False
                              )
# Out:
# loaded model 'projects/xf_11110_vggenc.py/model/e_1000.pth'
# loaded model 'projects/xf_11110_vggenc.py/model/g_1000.pth'
# <img src="data:image/png;base64,..." width="1000">
