# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
from ld_gan import visualize
import numpy as np
import ld_gan

# %% [markdown]
# # load data

# %%
#X, Y, VF = ld_gan.tmp.load_imgs_and_vgg()
#n_classes = Y.max()+1

X, Y = ld_gan.data_proc.data_loader.load_data(1, verbose=1, resize = 64)

#X, Y = ld_gan.data_proc.data_loader.load_data(1, verbose=1)
# Out:
# 100%|██████████| 102/102 [00:17<00:00,  7.14it/s]
# load data from '/export/home/oblum/projects/ls_gan/data/flowers_102/jpg_128'

# %%
#yc = Y
yc = np.argmax(Y, axis = 1)

# %% [markdown]
# # show

# %%
#xf_111110_loctrip_mc.py
#xf_11111_mc
visualize.tsne_to_interpol_arr(X, yc,  
                               "xf_11111_mc.py", 
                               600,  
                               z_mapped = None,
                               n_neighbors = 4,
                               sampler=None,
                               alpha = 0.3,
                               n_pts_tsne = 4000,
                               real_img_mode = "all+mean",
                               small = False
                              )
# Out:
# loaded model 'projects/xf_11111_mc.py/model/e_0600.pth'
# loaded model 'projects/xf_11111_mc.py/model/g_0600.pth'
# compute tsne...
# <img src="data:image/png;base64,..." width="1000">
