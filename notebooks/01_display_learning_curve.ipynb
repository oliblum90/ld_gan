# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("../")

# %matplotlib notebook
import matplotlib.pylab as plt
# pylab.rcParams['figure.figsize'] = (10, 5)

# %%
from ld_gan import visualize
import numpy as np

# %%
visualize.learning_curve_ia(
                            "xf_enc.py", 
                            high_res=True,
                            show_hist_tsne=True
                            )
# Out:
# <img src="data:image/png;base64,..." width="1349.9999707395386">

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2, 
            random_state=0, 
            metric = 'cosine', 
            learning_rate=1000)

# %%
z = np.random.rand(1000*256).reshape((1000, 256))

# %%
z.shape
# Out:
# (1000, 256)

# %%
tsne.fit_transform(z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-e6b1d77fa0d2> in <module>()
# ----> 1 tsne.fit_transform(z)
#
# /net/hciserver03/storage/oblum/venvs/compvisgpu01/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in fit_transform(self, X, y)
#     857             Embedding of the training data in low-dimensional space.
#     858         """
# --> 859         embedding = self._fit(X)
#     860         self.embedding_ = embedding
#     861         return self.embedding_
#
# /net/hciserver03/storage/oblum/venvs/compvisgpu01/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _fit(self, X, skip_num_points)
#     716                 neighbors_method = 'brute'
#     717             knn = NearestNeighbors(algorithm=neighbors_method, n_neighbors=k,
# --> 718                                    metric=self.metric)
#     719             t0 = time()
#     720             knn.fit(X)
#
# /net/hciserver03/storage/oblum/venvs/compvisgpu01/lib/python2.7/site-packages/sklearn/neighbors/unsupervised.pyc in __init__(self, n_neighbors, radius, algorithm, leaf_size, metric, p, metric_params, n_jobs, **kwargs)
#     121                           algorithm=algorithm,
#     122                           leaf_size=leaf_size, metric=metric, p=p,
# --> 123                           metric_params=metric_params, n_jobs=n_jobs, **kwargs)
#
# /net/hciserver03/storage/oblum/venvs/compvisgpu01/lib/python2.7/site-packages/sklearn/neighbors/base.pyc in _init_params(self, n_neighbors, radius, algorithm, leaf_size, metric, p, metric_params, n_jobs)
#     141         elif metric not in VALID_METRICS[alg_check]:
#     142             raise ValueError("Metric '%s' not valid for algorithm '%s'"
# --> 143                              % (metric, algorithm))
#     144
#     145         if self.metric_params is not None and 'p' in self.metric_params:
#
# ValueError: Metric 'cosine' not valid for algorithm 'ball_tree'

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '0.19.0'
